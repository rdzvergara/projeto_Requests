# %%
import requests

# %%
r = requests.get('https://api.github.com/events')

# %%
r
# Out:
# <Response [200]>

# %%
r.status_code
# Out:
# 200

# %%
r.url
# Out:
# 'https://api.github.com/events'

# %%
r.text
# Out:
# '[{"id":"9343575044","type":"PushEvent","actor":{"id":60653600,"login":"mix113","display_login":"mix113","gravatar_id":"","url":"https://api.github.com/users/mix113","avatar_url":"https://avatars.githubusercontent.com/u/60653600?"},"repo":{"id":1133518622,"name":"mix113/leaders-image","url":"https://api.github.com/repos/mix113/leaders-image"},"payload":{"repository_id":1133518622,"push_id":31637129004,"ref":"refs/heads/main","head":"bec34ef856853d276cf6945c9c80547cf55c496e","before":"17277ccf4be1f4e8699c2ac0b806c895568da950"},"public":true,"created_at":"2026-03-13T00:09:58Z"},{"id":"9343575234","type":"PushEvent","actor":{"id":19983904,"login":"lavraicse","display_login":"lavraicse","gravatar_id":"","url":"https://api.github.com/users/lavraicse","avatar_url":"https://avatars.githubusercontent.com/u/19983904?"},"repo":{"id":1180332610,"name":"lavraicse/githubpages-test","url":"https://api.github.com/repos/lavraicse/githubpages-test"},"payload":{"repository_id":1180332610,"push_id":316
# ...

# %%
r.json()
# Out:
# [{'id': '9343575044',
#   'type': 'PushEvent',
#   'actor': {'id': 60653600,
#    'login': 'mix113',
#    'display_login': 'mix113',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mix113',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/60653600?'},
#   'repo': {'id': 1133518622,
#    'name': 'mix113/leaders-image',
#    'url': 'https://api.github.com/repos/mix113/leaders-image'},
#   'payload': {'repository_id': 1133518622,
#    'push_id': 31637129004,
#    'ref': 'refs/heads/main',
#    'head': 'bec34ef856853d276cf6945c9c80547cf55c496e',
#    'before': '17277ccf4be1f4e8699c2ac0b806c895568da950'},
#   'public': True,
#   'created_at': '2026-03-13T00:09:58Z'},
#  {'id': '9343575234',
#   'type': 'PushEvent',
#   'actor': {'id': 19983904,
#    'login': 'lavraicse',
#    'display_login': 'lavraicse',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/lavraicse',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19983904?'},
# ...

# %%
r = requests.get('https://api.github.com/versions')
r.text
# Out:
# '["2026-03-10","2022-11-28"]'

# %%
headers = {'X-GitHub-Api-Version': '2022-11-28'}
r = requests.get('https://api.github.com/events', headers=headers)
r.json()
# Out:
# [{'id': '9343575044',
#   'type': 'PushEvent',
#   'actor': {'id': 60653600,
#    'login': 'mix113',
#    'display_login': 'mix113',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mix113',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/60653600?'},
#   'repo': {'id': 1133518622,
#    'name': 'mix113/leaders-image',
#    'url': 'https://api.github.com/repos/mix113/leaders-image'},
#   'payload': {'repository_id': 1133518622,
#    'push_id': 31637129004,
#    'ref': 'refs/heads/main',
#    'head': 'bec34ef856853d276cf6945c9c80547cf55c496e',
#    'before': '17277ccf4be1f4e8699c2ac0b806c895568da950'},
#   'public': True,
#   'created_at': '2026-03-13T00:09:58Z'},
#  {'id': '9343575234',
#   'type': 'PushEvent',
#   'actor': {'id': 19983904,
#    'login': 'lavraicse',
#    'display_login': 'lavraicse',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/lavraicse',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19983904?'},
# ...

# %%
" DESAFIO 1 - Faça uma requisição pegando os dados de um Usuário do GitHub "

req = requests.get('https://api.github.com/users/rdzvergara')
req.status_code
# Out:
# 200

# %%
req.json()
# Out:
# {'login': 'rdzvergara',
#  'id': 48964173,
#  'node_id': 'MDQ6VXNlcjQ4OTY0MTcz',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/48964173?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/rdzvergara',
#  'html_url': 'https://github.com/rdzvergara',
#  'followers_url': 'https://api.github.com/users/rdzvergara/followers',
#  'following_url': 'https://api.github.com/users/rdzvergara/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/rdzvergara/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/rdzvergara/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/rdzvergara/subscriptions',
#  'organizations_url': 'https://api.github.com/users/rdzvergara/orgs',
#  'repos_url': 'https://api.github.com/users/rdzvergara/repos',
#  'events_url': 'https://api.github.com/users/rdzvergara/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/rdzvergara/received_events',
#  'type': 'User',
# ...

# %%
req.url
# Out:
# 'https://api.github.com/users/rdzvergara'

# %%
data = req.json()

resposta = { 
    'name': data.get('name'),
    'login': data.get('login'),
    'public_repos': data.get('public_repos'),
    'created_at': data.get('created_at')
    }

print(resposta)
# Out:
# {'name': 'Rodrigo Luiz de Mattos Vergara', 'login': 'rdzvergara', 'public_repos': 8, 'created_at': '2019-03-26T18:54:59Z'}

# %%
headers = {'X-GitHub-Api-Version': '2022-11-28'}

# %%
api_base_url = 'https://api.github.com'
owner = 'amzn' # Usuário que vamos extrair os dados
url = f'{api_base_url}/users/{owner}'

# %%
resposta = requests.get(url, headers=headers)
resposta.status_code
# Out:
# 200

# %%
resposta.json()
# Out:
# {'login': 'amzn',
#  'id': 8594673,
#  'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/amzn',
#  'html_url': 'https://github.com/amzn',
#  'followers_url': 'https://api.github.com/users/amzn/followers',
#  'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#  'organizations_url': 'https://api.github.com/users/amzn/orgs',
#  'repos_url': 'https://api.github.com/users/amzn/repos',
#  'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/amzn/received_events',
#  'type': 'Organization',
#  'user_view_type': 'public',
#  'site_admin': False,
# ...

# %%
len(resposta.json())
# Out:
# 33

# %%
accesss_token = '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'
headers = {
    'X-GitHub-Api-Version': '2022-11-28',
    'Authorization': 'Bearer ' + accesss_token
}

# %%
api_base_url = 'https://api.github.com'
owner = 'amzn' # Usuário que vamos extrair os dados
url = f'{api_base_url}/users/{owner}/repos'

# %%
repos_list = []
for page_num in range(1, 6):
    try:
        url_page = f'{url}?page={page_num}'
        resposta = requests.get(url_page, headers= headers)
        repos_list.append(resposta.json())
    except:
        repos_list.append(None)

# %%
repos_list
# Out:
# [[{'id': 171339259,
#    'node_id': 'MDEwOlJlcG9zaXRvcnkxNzEzMzkyNTk=',
#    'name': '.github',
#    'full_name': 'amzn/.github',
#    'private': False,
#    'owner': {'login': 'amzn',
#     'id': 8594673,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/amzn',
#     'html_url': 'https://github.com/amzn',
#     'followers_url': 'https://api.github.com/users/amzn/followers',
#     'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#     'organizations_url': 'https://api.github.com/users/amzn/orgs',
#     'repos_url': 'https://api.github.com/users/amzn/repos',
# ...

# %%
len(repos_list)
# Out:
# 5

# %%
len(repos_list[0])
# Out:
# 30

# %%
repos_list[0]
# Out:
# [{'id': 171339259,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkxNzEzMzkyNTk=',
#   'name': '.github',
#   'full_name': 'amzn/.github',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
# ...

# %%
repos_list[0][10]
# Out:
# {'id': 225431811,
#  'node_id': 'MDEwOlJlcG9zaXRvcnkyMjU0MzE4MTE=',
#  'name': 'amazon-hub-counter-api-docs',
#  'full_name': 'amzn/amazon-hub-counter-api-docs',
#  'private': False,
#  'owner': {'login': 'amzn',
#   'id': 8594673,
#   'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/amzn',
#   'html_url': 'https://github.com/amzn',
#   'followers_url': 'https://api.github.com/users/amzn/followers',
#   'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#   'organizations_url': 'https://api.github.com/users/amzn/orgs',
#   'repos_url': 'https://api.github.com/users/amzn/repos',
# ...

# %%
# DESAFIO 2 - Faça uma requisição pegando os seguidores de um usuário do GitHub
username = 'amzn'
url = f'https://api.github.com/users/{username}/followers'
headers = {
    'X-GitHub-Api-Version': '2022-11-28',
    'Authorization': 'Bearer ' + accesss_token
}

response = requests.get(url, headers=headers)
followers = response.json()

# %%
followers_list = []
i = 1

while True:
    url_page = f'{url}?page={i}'
    response = requests.get(url_page, headers=headers)

    if len(response.json()) == 0:
       break
    followers_list.append(response.json())
    i += 1
    print(len(response.json()))
# Out:
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 25

# %%
repos_list[0][2]['name']
# Out:
# 'ads-pao-amznjs-gtm-server-side-template'

# %%
repos_name = []

for page in repos_list:
    for repo in page:
        repos_name.append(repo['name'])

# %%
repos_name[:10]
# Out:
# ['.github',
#  'ads-advanced-tools-docs',
#  'ads-pao-amznjs-gtm-server-side-template',
#  'ads-pao-amznjs-gtm-template',
#  'alexa-coho',
#  'alexa-skills-kit-js',
#  'amazon-ads-advertiser-audience-normalization-sdk-py',
#  'amazon-advertising-api-php-sdk',
#  'amazon-codeguru-profiler-for-spark',
#  'amazon-frustration-free-setup-certification-tool']

# %%
len(repos_name)
# Out:
# 150

# %%
repos_list[1][1]['language']
# Out:
# 'PHP'

# %%
repos_language = []

for page in repos_list:
    for repo in page:
        #if repo['language'] is not None:
          repos_language.append(repo['language'])

repos_language[:10]
# Out:
# [None,
#  'Jupyter Notebook',
#  'Smarty',
#  'Smarty',
#  'JavaScript',
#  None,
#  'Python',
#  'PHP',
#  'Java',
#  'Python']

# %%
import pandas as pd

# %%
dados_amz = pd.DataFrame()
dados_amz['repository_name'] = repos_name
dados_amz['language'] = repos_language

# %%
dados_amz
# Out:
#                              repository_name          language
# 0                                    .github              None
# 1                    ads-advanced-tools-docs  Jupyter Notebook
# 2    ads-pao-amznjs-gtm-server-side-template            Smarty
# 3                ads-pao-amznjs-gtm-template            Smarty
# 4                                 alexa-coho        JavaScript
# ..                                       ...               ...
# 145                          smoke-framework             Swift
# 146     smoke-framework-application-generate             Swift
# 147                 smoke-framework-examples             Swift
# 148                               smoke-http             Swift
# 149                             sparse-vqvae            Python
#
# [150 rows x 2 columns]

# %%
dados_amz.to_csv('amazon.csv', index=True)

# %%
# Desafio 3 - Gere um arquivo CSV com os nomes dos seguidores do Github
followers_names = []

for page in followers_list:
    for repo in page:
        followers_names.append(repo['login'])

len(followers_names)
# Out:
# 2515

# %%
seguidores_amzn = pd.DataFrame({'nome': followers_names})
seguidores_amzn
# Out:
#                   nome
# 0              tkersey
# 1             njonsson
# 2            bangpound
# 3           vincentkoc
# 4                Rud5G
# ...                ...
# 2510        richi-reds
# 2511          villagga
# 2512        quanphoton
# 2513          yulinlyl
# 2514  charlotte-otoole
#
# [2515 rows x 1 columns]

# %%
seguidores_amzn.to_csv('seguidores.csv', index=True, index_label='id')

# %%
api_base_url = 'https://api.github.com'
url = f'{api_base_url}/user/repos'

headers
# Out:
# {'X-GitHub-Api-Version': '2022-11-28',
#  'Authorization': 'Bearer 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'}

# %%
data = {
    'name' : 'linguagens-utilizadas',
    'description' : 'Repositório para armazenar as linguagens utilizadas nos repositórios da Amazon',
    'private' : False
}

reposta = requests.post(url, headers=headers, json=data)
reposta.status_code
# Out:
# 200

# %%
import base64

# %%
# Envio do arquivo amazon para o repositório do github
with open('amazon.csv', 'rb') as file:
    file_content = file.read()

encoded_content = base64.b64encode(file_content).decode('utf-8')
api_base_url = 'https://api.github.com'
username = 'rdzvergara'
repo = 'linguagens-utilizadas'
file_path = 'amazon.csv'

url = f'{api_base_url}/repos/{username}/{repo}/contents/{file_path}'
headers = {
    'X-GitHub-Api-Version': '2022-11-28',
    'Authorization': 'Bearer ' + accesss_token
}

data = {
    'message' : 'Adicionando o arquivo amazon.csv',
    'content' : encoded_content
}

response = requests.put(url, headers=headers, json=data)
response.status_code
# Out:
# 201

# %%
# Envio do arquivo seguidores para o repositório do github
with open('seguidores.csv', 'rb') as file:
    file_content = file.read()

encoded_content = base64.b64encode(file_content).decode('utf-8')
api_base_url = 'https://api.github.com'
username = 'rdzvergara'
repo = 'linguagens-utilizadas'
file_path = 'seguidores.csv'

url = f'{api_base_url}/repos/{username}/{repo}/contents/{file_path}'
headers = {
    'X-GitHub-Api-Version': '2022-11-28',
    'Authorization': 'Bearer ' + accesss_token
}

data = {
    'message' : 'Adicionando o arquivo seguidores.csv',
    'content' : encoded_content
}

response = requests.put(url, headers=headers, json=data)
response.status_code
# Out:
# 201

# %%
api_base_url = 'https://api.github.com'
username = 'amzn'
repo = 'app-platform'
file_path = 'seguidores.csv'

url = f'{api_base_url}/repos/{username}/{repo}/forks'
headers = {
    'Accept' : 'application/vnd.github+json',
    'X-GitHub-Api-Version': '2022-11-28',
    'Authorization': 'Bearer ' + accesss_token
}
data = {
    'name' : 'fork-amazon',
    'default_branch_only' : True
}

reposta = requests.post(url, headers=headers, json=data)
reposta.status_code
# Out:
# 202
